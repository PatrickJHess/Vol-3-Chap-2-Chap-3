# %% [markdown]
# # Here the fileid is returned, howeve, if it's jupyter notebook downloaded from github site, it will be the name of the notebook

# %%
# !pip install ipynbname -q
import ipynbname

try:
    # Call the notebook_name() function directly from the library
    notebook_name = ipynbname.name()
    print(f"The name of this notebook is: {notebook_name}")
except Exception as e:
    print(f"Could not get the notebook name. Error: {e}")
loc=notebook_name.find('_')-1
notebook_name[loc:]
# Out:
# Could not get the notebook name. Error: list index out of range
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24241/3475516374.py in <module>
#       8 except Exception as e:
#       9     print(f"Could not get the notebook name. Error: {e}")
# ---> 10 loc=notebook_name.find('_')-1
#      11 notebook_name[loc:]
#
# NameError: name 'notebook_name' is not defined

# %% [markdown]
# ### Test

# %%
print(10)

# %% [markdown]
# ## more
